# %% [markdown]
# # Using LlamaIndex to ingest web domain data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
# !{sys.executable} -m pip install -r../requirements.txt
# Out:
# Requirement already satisfied: numpy==1.24.2 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (1.24.2)
# Requirement already satisfied: openai==0.27.1 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (0.27.1)
# Requirement already satisfied: pandas==1.5.3 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: redis==4.5.1 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (4.5.1)
# Requirement already satisfied: requests==2.28.2 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (2.28.2)
# Requirement already satisfied: streamlit==1.20.0 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (1.20.0)
# Requirement already satisfied: streamlit_chat==0.0.2.2 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 7)) (0.0.2.2)
# Requirement already satisfied: termcolor==2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: jupyter in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: ipykernel in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 10)) (6.23.1)
# Requirement already satisfied: textract in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 11)) (1.6.5)
# Requirement already satisfied: tiktoken in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 12)) (0.4.0)
# Requirement already satisfied: pdfminer in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 13)) (20191125)
# Requirement already satisfied: llama-index in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 14)) (0.6.21.post1)
# Collecting pypdf (from -r ../requirements.txt (line 15))
#   Downloading pypdf-3.9.1-py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.3/249.3 kB 3.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scrapy in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 16)) (2.9.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 17)) (3.7.1)
# Requirement already satisfied: plotly in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 18)) (5.14.1)
# Requirement already satisfied: scipy in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 19)) (1.10.1)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (from -r ../requirements.txt (line 20)) (1.2.2)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from openai==0.27.1->-r ../requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: aiohttp in /opt/homebrew/lib/python3.11/site-packages (from openai==0.27.1->-r ../requirements.txt (line 2)) (3.8.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas==1.5.3->-r ../requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas==1.5.3->-r ../requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/homebrew/lib/python3.11/site-packages (from redis==4.5.1->-r ../requirements.txt (line 4)) (4.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.28.2->-r ../requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.28.2->-r ../requirements.txt (line 5)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.28.2->-r ../requirements.txt (line 5)) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.28.2->-r ../requirements.txt (line 5)) (2023.5.7)
# Requirement already satisfied: altair<5,>=3.2.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (4.2.2)
# Requirement already satisfied: blinker>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (1.6.2)
# Requirement already satisfied: cachetools>=4.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (5.3.1)
# Requirement already satisfied: click>=7.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (8.1.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (6.6.0)
# Requirement already satisfied: packaging>=14.1 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (9.5.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (12.0.0)
# Requirement already satisfied: pympler>=0.9 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (13.0.1)
# Requirement already satisfied: semver in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: toml in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (4.5.0)
# Requirement already satisfied: tzlocal>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (5.0.1)
# Requirement already satisfied: validators>=0.2 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (3.1.31)
# Requirement already satisfied: pydeck>=0.1.dev5 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (0.8.1b0)
# Requirement already satisfied: tornado>=6.0.3 in /opt/homebrew/lib/python3.11/site-packages (from streamlit==1.20.0->-r ../requirements.txt (line 6)) (6.3.2)
# Requirement already satisfied: notebook in /opt/homebrew/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 9)) (6.5.4)
# Requirement already satisfied: qtconsole in /opt/homebrew/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 9)) (5.4.3)
# Requirement already satisfied: jupyter-console in /opt/homebrew/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 9)) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/homebrew/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 9)) (7.4.0)
# Requirement already satisfied: ipywidgets in /opt/homebrew/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 9)) (8.0.6)
# Requirement already satisfied: appnope in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (8.13.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (1.5.6)
# Requirement already satisfied: psutil in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/homebrew/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: argcomplete~=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (1.10.3)
# Requirement already satisfied: beautifulsoup4~=4.8.0 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (4.8.2)
# Requirement already satisfied: chardet==3.* in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (3.0.4)
# Requirement already satisfied: docx2txt~=0.8 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (0.8)
# Requirement already satisfied: extract-msg<=0.29.* in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (0.28.7)
# Requirement already satisfied: pdfminer.six==20191110 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (20191110)
# Requirement already satisfied: python-pptx~=0.6.18 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (0.6.21)
# Requirement already satisfied: six~=1.12.0 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (1.12.0)
# Requirement already satisfied: SpeechRecognition~=3.8.1 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (3.8.1)
# Requirement already satisfied: xlrd~=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from textract->-r ../requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: pycryptodome in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six==20191110->textract->-r ../requirements.txt (line 11)) (3.18.0)
# Requirement already satisfied: sortedcontainers in /opt/homebrew/lib/python3.11/site-packages (from pdfminer.six==20191110->textract->-r ../requirements.txt (line 11)) (2.4.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/homebrew/lib/python3.11/site-packages (from tiktoken->-r ../requirements.txt (line 12)) (2023.5.5)
# Requirement already satisfied: dataclasses-json in /opt/homebrew/lib/python3.11/site-packages (from llama-index->-r ../requirements.txt (line 14)) (0.5.7)
# Requirement already satisfied: langchain>=0.0.154 in /opt/homebrew/lib/python3.11/site-packages (from llama-index->-r ../requirements.txt (line 14)) (0.0.187)
# Requirement already satisfied: sqlalchemy>=2.0.15 in /opt/homebrew/lib/python3.11/site-packages (from llama-index->-r ../requirements.txt (line 14)) (2.0.15)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index->-r ../requirements.txt (line 14)) (8.2.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index->-r ../requirements.txt (line 14)) (2023.5.0)
# Requirement already satisfied: typing-inspect==0.8.0 in /opt/homebrew/lib/python3.11/site-packages (from llama-index->-r ../requirements.txt (line 14)) (0.8.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect==0.8.0->llama-index->-r ../requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: Twisted>=18.9.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (22.10.0)
# Requirement already satisfied: cryptography>=3.4.6 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (41.0.0)
# Requirement already satisfied: cssselect>=0.9.1 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (23.2.0)
# Requirement already satisfied: queuelib>=1.4.2 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (21.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (2.1.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (6.0)
# Requirement already satisfied: protego>=0.1.15 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (0.2.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (0.8.0)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (67.6.1)
# Requirement already satisfied: tldextract in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (3.4.4)
# Requirement already satisfied: lxml>=4.3.0 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (4.9.2)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /opt/homebrew/lib/python3.11/site-packages (from scrapy->-r ../requirements.txt (line 16)) (2.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 17)) (3.0.9)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 20)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 20)) (3.1.0)
# Requirement already satisfied: entrypoints in /opt/homebrew/lib/python3.11/site-packages (from altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (0.4)
# Requirement already satisfied: jinja2 in /opt/homebrew/lib/python3.11/site-packages (from altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (4.17.3)
# Requirement already satisfied: toolz in /opt/homebrew/lib/python3.11/site-packages (from altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: soupsieve>=1.2 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4~=4.8.0->textract->-r ../requirements.txt (line 11)) (2.4.1)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/lib/python3.11/site-packages (from cryptography>=3.4.6->scrapy->-r ../requirements.txt (line 16)) (1.15.1)
# Requirement already satisfied: imapclient==2.1.0 in /opt/homebrew/lib/python3.11/site-packages (from extract-msg<=0.29.*->textract->-r ../requirements.txt (line 11)) (2.1.0)
# Requirement already satisfied: olefile>=0.46 in /opt/homebrew/lib/python3.11/site-packages (from extract-msg<=0.29.*->textract->-r ../requirements.txt (line 11)) (0.46)
# Requirement already satisfied: compressed-rtf>=1.0.6 in /opt/homebrew/lib/python3.11/site-packages (from extract-msg<=0.29.*->textract->-r ../requirements.txt (line 11)) (1.0.6)
# Requirement already satisfied: ebcdic>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from extract-msg<=0.29.*->textract->-r ../requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from gitpython!=3.1.19->streamlit==1.20.0->-r ../requirements.txt (line 6)) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata>=1.4->streamlit==1.20.0->-r ../requirements.txt (line 6)) (3.15.0)
# Requirement already satisfied: backcall in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.2.0)
# Requirement already satisfied: decorator in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.18.2)
# Requirement already satisfied: pickleshare in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (2.15.1)
# Requirement already satisfied: stack-data in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (4.8.0)
# Requirement already satisfied: jmespath>=0.9.5 in /opt/homebrew/lib/python3.11/site-packages (from itemloaders>=1.0.1->scrapy->-r ../requirements.txt (line 16)) (1.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 10)) (3.5.1)
# Requirement already satisfied: PyYAML>=5.4.1 in /opt/homebrew/lib/python3.11/site-packages (from langchain>=0.0.154->llama-index->-r ../requirements.txt (line 14)) (6.0)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain>=0.0.154->llama-index->-r ../requirements.txt (line 14)) (2.8.4)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /opt/homebrew/lib/python3.11/site-packages (from langchain>=0.0.154->llama-index->-r ../requirements.txt (line 14)) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /opt/homebrew/lib/python3.11/site-packages (from langchain>=0.0.154->llama-index->-r ../requirements.txt (line 14)) (1.10.8)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->openai==0.27.1->-r ../requirements.txt (line 2)) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->openai==0.27.1->-r ../requirements.txt (line 2)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->openai==0.27.1->-r ../requirements.txt (line 2)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->openai==0.27.1->-r ../requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp->openai==0.27.1->-r ../requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json->llama-index->-r ../requirements.txt (line 14)) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json->llama-index->-r ../requirements.txt (line 14)) (1.5.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /opt/homebrew/lib/python3.11/site-packages (from python-pptx~=0.6.18->textract->-r ../requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from rich>=10.11.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (0.9.1)
# Requirement already satisfied: pyasn1-modules in /opt/homebrew/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy->-r ../requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: pyasn1 in /opt/homebrew/lib/python3.11/site-packages (from service-identity>=18.1.0->scrapy->-r ../requirements.txt (line 16)) (0.5.0)
# Requirement already satisfied: constantly>=15.1 in /opt/homebrew/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy->-r ../requirements.txt (line 16)) (15.1.0)
# Requirement already satisfied: incremental>=21.3.0 in /opt/homebrew/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy->-r ../requirements.txt (line 16)) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in /opt/homebrew/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy->-r ../requirements.txt (line 16)) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /opt/homebrew/lib/python3.11/site-packages (from Twisted>=18.9.0->scrapy->-r ../requirements.txt (line 16)) (21.0.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 9)) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 9)) (3.0.7)
# Requirement already satisfied: bleach in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (6.0.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (2.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.8.0)
# Requirement already satisfied: nbformat>=5.1 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (5.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/homebrew/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->-r ../requirements.txt (line 9)) (21.3.0)
# Requirement already satisfied: ipython-genutils in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->-r ../requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->-r ../requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->-r ../requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->-r ../requirements.txt (line 9)) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/homebrew/lib/python3.11/site-packages (from notebook->jupyter->-r ../requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: qtpy>=2.0.1 in /opt/homebrew/lib/python3.11/site-packages (from qtconsole->jupyter->-r ../requirements.txt (line 9)) (2.3.1)
# Requirement already satisfied: requests-file>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from tldextract->scrapy->-r ../requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /opt/homebrew/lib/python3.11/site-packages (from tldextract->scrapy->-r ../requirements.txt (line 16)) (3.12.0)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.6->scrapy->-r ../requirements.txt (line 16)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/homebrew/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.20.0->-r ../requirements.txt (line 6)) (5.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (0.19.3)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/homebrew/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/homebrew/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/lib/python3.11/site-packages (from nbformat>=5.1->nbconvert->jupyter->-r ../requirements.txt (line 9)) (2.17.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter->-r ../requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: webencodings in /opt/homebrew/lib/python3.11/site-packages (from bleach->nbconvert->jupyter->-r ../requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (2.2.1)
# Requirement already satisfied: pure-eval in /opt/homebrew/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (0.4.4)
# Requirement already satisfied: overrides in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (7.3.1)
# Requirement already satisfied: websocket-client in /opt/homebrew/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (1.5.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/homebrew/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/homebrew/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->-r ../requirements.txt (line 9)) (0.1.1)
# Requirement already satisfied: fqdn in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: isoduration in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (2.3)
# Requirement already satisfied: uri-template in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/homebrew/lib/python3.11/site-packages (from isoduration->jsonschema>=3.0->altair<5,>=3.2.0->streamlit==1.20.0->-r ../requirements.txt (line 6)) (1.2.3)
# Installing collected packages: pypdf
# Successfully installed pypdf-3.9.1

# %% [markdown]
# ## Setup
#
# First we'll setup our libraries and environment variables

# %%
import openai
import os
import requests
import numpy as np
import pandas as pd
from typing import Iterator
import tiktoken
import textract
from numpy import array, average

from database import get_redis_connection

# Set our default models and chunking size
from config import COMPLETIONS_MODEL, EMBEDDINGS_MODEL, CHAT_MODEL, TEXT_EMBEDDING_CHUNK_SIZE, VECTOR_FIELD_NAME

# Ignore unclosed SSL socket warnings - optional in case you get these errors
import warnings

warnings.filterwarnings(action="ignore", message="unclosed", category=ImportWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)  #%% md
# Using LlamaIndex to ingest web domain data

# %%
pd.set_option('display.max_colwidth', 0)

# %% [markdown]
# ## Storage
#
# We're going to use Redis as our database for both document contents and the vector embeddings. You will need the full Redis Stack to enable use of Redisearch, which is the module that allows semantic search - more detail is in the [docs for Redis Stack](https://redis.io/docs/stack/get-started/install/docker/).
#
# To set this up locally, you will need to install Docker and then run the following command: ```docker run -d --name redis-stack -p 6379:6379 -p 8001:8001 redis/redis-stack:latest```.
#
# The code used here draws heavily on [this repo](https://github.com/RedisAI/vecsim-demo).
#
# After setting up the Docker instance of Redis Stack, you can follow the below instructions to initiate a Redis connection and create a Hierarchical Navigable Small World (HNSW) index for semantic search.

# %%
# Setup Redis and running?
from database import get_redis_connection

redis_client = get_redis_connection()

redis_client.ping()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/redis/connection.py:715, in Connection.connect(self)
#     714 try:
# --> 715     sock = self.retry.call_with_retry(
#     716         lambda: self._connect(), lambda error: self.disconnect(error)
#     717     )
#     718 except socket.timeout:
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/retry.py:46, in Retry.call_with_retry(self, do, fail)
#      45 try:
# ---> 46     return do()
#      47 except self._supported_errors as error:
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/connection.py:716, in Connection.connect.<locals>.<lambda>()
#     714 try:
#     715     sock = self.retry.call_with_retry(
# --> 716         lambda: self._connect(), lambda error: self.disconnect(error)
#     717     )
#     718 except socket.timeout:
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/connection.py:781, in Connection._connect(self)
#     780 if err is not None:
# --> 781     raise err
#     782 raise OSError("socket.getaddrinfo returned an empty list")
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/connection.py:769, in Connection._connect(self)
#     768 # connect
# --> 769 sock.connect(socket_address)
#     771 # set the socket_timeout now that we're connected
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[5], line 6
#       2 from database import get_redis_connection
#       4 redis_client = get_redis_connection()
# ----> 6 redis_client.ping()
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/commands/core.py:1194, in ManagementCommands.ping(self, **kwargs)
#    1188 def ping(self, **kwargs) -> ResponseT:
#    1189     """
#    1190     Ping the Redis server
#    1191
#    1192     For more information see https://redis.io/commands/ping
#    1193     """
# -> 1194     return self.execute_command("PING", **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/client.py:1255, in Redis.execute_command(self, *args, **options)
#    1253 pool = self.connection_pool
#    1254 command_name = args[0]
# -> 1255 conn = self.connection or pool.get_connection(command_name, **options)
#    1257 try:
#    1258     return conn.retry.call_with_retry(
#    1259         lambda: self._send_command_parse_response(
#    1260             conn, command_name, *args, **options
#    1261         ),
#    1262         lambda error: self._disconnect_raise(conn, error),
#    1263     )
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/connection.py:1481, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1477     self._in_use_connections.add(connection)
#    1479 try:
#    1480     # ensure this connection is connected to Redis
# -> 1481     connection.connect()
#    1482     # connections that the pool provides should be ready to send
#    1483     # a command. if not, the connection was either returned to the
#    1484     # pool before all data has been read or the socket has been
#    1485     # closed. either way, reconnect and verify everything is good.
#    1486     try:
#
# File /opt/homebrew/lib/python3.11/site-packages/redis/connection.py:721, in Connection.connect(self)
#     719     raise TimeoutError("Timeout connecting to server")
#     720 except OSError as e:
# --> 721     raise ConnectionError(self._error_message(e))
#     723 self._sock = sock
#     724 try:
#
# ConnectionError: Error 61 connecting to localhost:6379. Connection refused.

# %%
# Optional step to drop the index if it already exists
from config import INDEX_NAME

redis_client.ft(INDEX_NAME).dropindex()
# Out:
# b'OK'

# %% [markdown]
# ## Web Text File Ingestion
# Using beautiful_soup_web connector provided by llamahub: https://llamahub.ai/l/web-beautiful_soup_web

# %%
from llama_index import download_loader

BeautifulSoupWebReader = download_loader("BeautifulSoupWebReader")

loader = BeautifulSoupWebReader()
documents = loader.load_data(urls=['https://focusedlabs.io', 'https://focusedlabs.io/about', 'https://focusedlabs.io/contact', 'https://focusedlabs.io/case-studies',         "https://focusedlabs.io/case-studies/agile-workflow-enabled-btr-automation",
        "https://focusedlabs.io/case-studies/hertz-technology-new-markets",
        "https://focusedlabs.io/case-studies/aperture-agile-transformation",
        "https://focusedlabs.io/case-studies/automated-core-business-functionality" ])
documents
# Out:
# [Document(text='\n\nA digital transformation partner focused on software delivery\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n\n  \n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num1:hover h2.title,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num1:hover h4.subtitle,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num1:hover p.description,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num1:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1669954611904 .flex_row_card .item.num1{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num2:hover h2.title,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num2:hover h4.subtitle,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num2:hover p.description,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num2:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1669954611904 .flex_row_card .item.num2{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num3:hover h2.title,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num3:hover h4.subtitle,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num3:hover p.description,\n  .cards_gallery_module.widget_1669954611904 .item.texteffect.num3:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1669954611904 .flex_row_card .item.num3{\n    padding: 0 15px;\n  }\n\n  \n  \n\n  .cards_gallery_module.widget_1669954611904 .content-wrapper{\n    padding: 0px;\n\n  }\n\n  \n\n  \n\n  \n\n\n  @media (max-width: 767px){\n    \n\n    \n\n\n    \n\n    \n\n  }\n\n\n\n\n\n\n\n\n  \n\n  .cards_gallery_module.module_16699707997373 .content-wrapper{\n    padding: 0px;\n\n  }\n\n  \n\n  \n\n  \n\n\n  @media (max-width: 767px){\n    \n\n    \n\n\n    \n\n    \n\n  }\n\n\n\n\n\n  \n  .cards_gallery_module.module_16699779029573 .item.texteffect.num1:hover h2.title,\n  .cards_gallery_module.module_16699779029573 .item.texteffect.num1:hover h4.subtitle,\n  .cards_gallery_module.module_16699779029573 .item.texteffect.num1:hover p.description,\n  .cards_gallery_module.module_16699779029573 .item.texteffect.num1:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.module_16699779029573 .flex_row_card .item.num1{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.module_16699779029573 .item.texteffect.num2:hover h2.title,\n  .cards_gallery_module.module_16699779029573 .item.texteffect.num2:hover h4.subtitle,\n  .cards_gallery_module.module_16699779029573 .item.texteffect.num2:hover p.description,\n  .cards_gallery_module.module_16699779029573 .item.texteffect.num2:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.module_16699779029573 .flex_row_card .item.num2{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gall ...
#  Document(text='\n\nWe are unintimidating and unintimidated technology consultants\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n\n  \n  .cards_gallery_module.module_16702361539975 .item.texteffect.num1:hover h2.title,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num1:hover h4.subtitle,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num1:hover p.description,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num1:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.module_16702361539975 .flex_row_card .item.num1{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.module_16702361539975 .item.texteffect.num2:hover h2.title,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num2:hover h4.subtitle,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num2:hover p.description,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num2:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.module_16702361539975 .flex_row_card .item.num2{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.module_16702361539975 .item.texteffect.num3:hover h2.title,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num3:hover h4.subtitle,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num3:hover p.description,\n  .cards_gallery_module.module_16702361539975 .item.texteffect.num3:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.module_16702361539975 .flex_row_card .item.num3{\n    padding: 0 15px;\n  }\n\n  \n  \n\n  .cards_gallery_module.module_16702361539975 .content-wrapper{\n    padding: 0px;\n\n  }\n\n  \n\n  \n\n  \n\n\n  @media (max-width: 767px){\n    \n\n    \n\n\n    \n\n    \n\n  }\n\n\n\n\n\n\n\n\n  \n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num1:hover h2.title,\n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num1:hover h4.subtitle,\n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num1:hover p.description,\n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num1:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670297781062 .flex_row_card .item.num1{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num2:hover h2.title,\n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num2:hover h4.subtitle,\n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num2:hover p.description,\n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num2:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670297781062 .flex_row_card .item.num2{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num3:hover h2.title,\n  .cards_gallery_module.widget_1670297781062 .item.texteffect.num3:hover h4.subtitle,\n  .cards_gallery_module.widget_16 ...
#  Document(text='\n\nA digital transformation partner focused on results\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n\n\n\n.hs_contact_row1-row-0-max-width-section-centering > .row-fluid {\n  max-width: 720px !important;\n  margin-left: auto !important;\n  margin-right: auto !important;\n}\n.hs_contact_row3-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n/* HubSpot Non-stacked Media Query Styles */\n@media (min-width:768px) {\n  .hs_contact_row1-row-0-vertical-alignment > .row-fluid {\n    display: -ms-flexbox !important;\n    -ms-flex-direction: row;\n    display: flex !important;\n    flex-direction: row;\n  }\n  .cell_1669869377743-vertical-alignment {\n    display: -ms-flexbox !important;\n    -ms-flex-direction: column !important;\n    -ms-flex-pack: center !important;\n    display: flex !important;\n    flex-direction: column !important;\n    justify-content: center !important;\n  }\n  .cell_1669869377743-vertical-alignment > div {\n    flex-shrink: 0 !important;\n  }\n  .cell_16698690133822-vertical-alignment {\n    display: -ms-flexbox !important;\n    -ms-flex-direction: column !important;\n    -ms-flex-pack: center !important;\n    display: flex !important;\n    flex-direction: column !important;\n    justify-content: center !important;\n  }\n  .cell_16698690133822-vertical-alignment > div {\n    flex-shrink: 0 !important;\n  }\n  .hs_contact_row2-row-0-vertical-alignment > .row-fluid {\n    display: -ms-flexbox !important;\n    -ms-flex-direction: row;\n    display: flex !important;\n    flex-direction: row;\n  }\n  .cell_16698696568422-vertical-alignment {\n    display: -ms-flexbox !important;\n    -ms-flex-direction: column !important;\n    -ms-flex-pack: start !important;\n    display: flex !important;\n    flex-direction: column !important;\n    justify-content: flex-start !important;\n  }\n  .cell_16698696568422-vertical-alignment > div {\n    flex-shrink: 0 !important;\n  }\n  .cell_1669870027356-vertical-alignment {\n    display: -ms-flexbox !important;\n    -ms-flex-direction: column !important;\n    -ms-flex-pack: start !important;\n    display: flex !important;\n    flex-direction: column !important;\n    justify-content: flex-start !important;\n  }\n  .cell_1669870027356-vertical-alignment > div {\n    flex-shrink: 0 !important;\n  }\n}\n/* HubSpot Styles (default) */\n.hs_contact_row1-row-0-padding {\n  padding-top: 5rem !important;\n}\n.cell_16698690133822-padding {\n  padding-left: 0px !important;\n}\n.widget_1669876418042-hidden {\n  display: none !important;\n}\n.hs_contact_row3-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n/* HubSpot Styles (mobile) */\n@media (max-width: 767px) {\n  .widget_1669876418042-hidden {\n    display: block !important;\n  }\n}\n\n\n\n\n\nvar _hsp = window._hsp = window._hsp || [];\n\nvar hsLoadGtm = function loadGtm() {\n    if(window._hsGtmLoadOnce) {\n      return;\n    }\n\n    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getEl ...
#  Document(text='\n\nFocused Labs\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n  .two-col-cont-cm.module_167030069617811 .left-col{\n    width: 40%;\n    padding-right: 0px;\n  }\n\n  .two-col-cont-cm.module_167030069617811 .right-col{\n    width: 60%;\n    padding-left: 0px;\n  }\n\n  .two-col-cont-cm.module_167030069617811 .two-col-wrap.fullwidth .left-col,\n  .two-col-cont-cm.module_167030069617811 .two-col-wrap.fullwidth .right-col{\n    padding-right: 0;\n    padding-left: 0;\n  }\n\n  .two-col-cont-cm.module_167030069617811 .left-col .content-outer-box{\n    padding: 20px;\n\n  }\n\n  .two-col-cont-cm.module_167030069617811 .right-col .content-outer-box{\n    padding: 20px;\n\n  }\n\n  .two-col-cont-cm.module_167030069617811 .left-col .content-inner{\n    font-size: 20px;\n    line-height: 1.5;\n    font-weight: 400;\n    color: rgba(0, 0, 0,1.0);\n  }\n\n  .two-col-cont-cm.module_167030069617811 .right-col .content-inner{\n    font-size: 20px;\n    line-height: 1.5;\n    font-weight: 400;\n    color: rgba(0, 0, 0,1.0);\n  }\n\n  .two-col-cont-cm.module_167030069617811 .flex-row.sepratoradded .left-col {\n    border-right: 1px solid rgba(0, 0, 0,1.0);\n  }\n\n  @media (max-width: 767px){\n    .two-col-cont-cm.module_167030069617811 .left-col{\n      padding-right: 0px;\n      width: 100%;\n    }\n\n    .two-col-cont-cm.module_167030069617811 .flex-row.sepratoradded .left-col {\n      border-right: 0;\n    }\n\n    .two-col-cont-cm.module_167030069617811 .right-col{\n      padding-left: 0px;\n      width: 100%;\n    }\n\n    .two-col-cont-cm.module_167030069617811 .flex-row.order_two {   \n      -webkit-box-orient: vertical;\n      -webkit-box-direction: reverse;\n      -ms-flex-direction: column-reverse;\n      flex-direction: column-reverse;\n    }\n\n    \n\n\n    \n\n    \n\n    \n\n  }\n\n\n  .two-col-cont-cm.module_16703026201904 .left-col{\n    width: 40%;\n    padding-right: 0px;\n  }\n\n  .two-col-cont-cm.module_16703026201904 .right-col{\n    width: 60%;\n    padding-left: 0px;\n  }\n\n  .two-col-cont-cm.module_16703026201904 .two-col-wrap.fullwidth .left-col,\n  .two-col-cont-cm.module_16703026201904 .two-col-wrap.fullwidth .right-col{\n    padding-right: 0;\n    padding-left: 0;\n  }\n\n  .two-col-cont-cm.module_16703026201904 .left-col .content-outer-box{\n    padding: 20px;\n\n  }\n\n  .two-col-cont-cm.module_16703026201904 .right-col .content-outer-box{\n    padding: 20px;\n\n  }\n\n  .two-col-cont-cm.module_16703026201904 .left-col .content-inner{\n    font-size: 20px;\n    line-height: 1.5;\n    font-weight: 400;\n    color: rgba(0, 0, 0,1.0);\n  }\n\n  .two-col-cont-cm.module_16703026201904 .right-col .content-inner{\n    font-size: 20px;\n    line-height: 1.5;\n    font-weight: 400;\n    color: rgba(0, 0, 0,1.0);\n  }\n\n  .two-col-cont-cm.module_16703026201904 .flex-row.sepratoradded .left-col {\n    border-right: 1px solid rgba(0, 0, 0,1.0);\n  }\n\n  @media (max-width: 767px){\n    .two-col-cont-cm.module_16703026201904 .left-col{\n      padding-right: 0px;\n      width: 100%;\n    }\n\n    .two-col-cont-cm.module_16703026201904 .flex-row.sepratoradded .left-col {\ ...
#  Document(text='\n\nFocused Labs\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n\n\n.hs_case_inner_row1-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row3-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n/* HubSpot Styles (default) */\n.hs_case_inner_row1-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row2-row-0-margin {\n  margin-top: -28px !important;\n}\n.cell_16703093224762-padding {\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row3-row-0-margin {\n  margin-top: -20px !important;\n}\n.hs_case_inner_row3-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 7.5rem !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n/* HubSpot Styles (mobile) */\n@media (max-width: 767px) {\n  .hs_case_inner_row3-row-0-margin {\n    margin-top: 0px !important;\n  }\n}\n\n\n\n\n\nvar _hsp = window._hsp = window._hsp || [];\n\nvar hsLoadGtm = function loadGtm() {\n    if(window._hsGtmLoadOnce) {\n      return;\n    }\n\n    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-MGP2TJH\');\n\n    window._hsGtmLoadOnce = true;\n};\n\nvar useGoogleConsentMode = false;\n\nif (!useGoogleConsentMode){\n    _hsp.push([\'addPrivacyConsentListener\', function(consent){\n      if(consent.allowed || (consent.categories && consent.categories.analytics)){\n        hsLoadGtm();\n      }\n  }]);\n} else{\n    if(!window._hsGoogleConsentRunOnce){\n      window._hsGoogleConsentRunOnce=true;\n\n      window.dataLayer=window.dataLayer||[];\n      function gtag(){dataLayer.push(arguments);}\n\n      gtag(\'consent\',\'default\',{\n        \'ad_storage\':\'denied\',\n        \'analytics_storage\':\'denied\'\n      });\n\n      gtag(\'set\',\'developer_id.dZTQ1Zm\',true);\n\n      _hsp.push([\'addPrivacyConsentListener\',function(consent){\n      var hasAnalyticsConsent=consent&&(consent.allowed||(consent.categories&&consent.categories.analytics));\n      var hasAdsConsent=consent&&(consent.allowed||(consent.categories&&consent.categories.advertisement));\n\n      gtag(\'consent\',\'update\',{\n        \'ad_storage\':hasAdsConsent?\'granted\':\'denied\',\n        \'analytics_storage\':hasAnalyticsConsent?\'granted\':\'denied\'\n      });\n    }]);\n  }\n\n  hsLoadGtm();\n}\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout\nServices\nBlog\nCareers\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCase study\n\n\n\n\n\n\n\n\n\nAgile Workflow Enabled Startup BTR Energy to Automate Workflows\n\n\nIndustry\nRenewable Energy; Semico ...
#  Document(text='\n\nFocused Labs\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n\n\n  \n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover h2.title,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover h4.subtitle,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover p.description,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670309355333 .flex_row_card .item.num1{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover h2.title,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover h4.subtitle,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover p.description,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670309355333 .flex_row_card .item.num2{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover h2.title,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover h4.subtitle,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover p.description,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670309355333 .flex_row_card .item.num3{\n    padding: 0 15px;\n  }\n\n  \n  \n\n  .cards_gallery_module.widget_1670309355333 .content-wrapper{\n    padding-top: 20px;\npadding-right: 0px;\npadding-bottom: 20px;\npadding-left: 0px;\n\n  }\n\n  \n\n  \n\n  \n\n\n  @media (max-width: 767px){\n    \n\n    \n\n\n    \n\n    \n\n  }\n\n\n\n\n\n\n\n\n.hs_case_inner_row1-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row2-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row2-row-1-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row3-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row3-row-1-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n/* HubSpot Styles (default) */\n.hs_case_inner_row1-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row2-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row2-row-1-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.cell_16703093224762-padding {\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row3-row-0-padding {\n  padding-top: 0px !important;\n  padding ...
#  Document(text='\n\nFocused Labs\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n\n\n  \n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover h2.title,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover h4.subtitle,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover p.description,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num1:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670309355333 .flex_row_card .item.num1{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover h2.title,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover h4.subtitle,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover p.description,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num2:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670309355333 .flex_row_card .item.num2{\n    padding: 0 15px;\n  }\n\n  \n  \n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover h2.title,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover h4.subtitle,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover p.description,\n  .cards_gallery_module.widget_1670309355333 .item.texteffect.num3:hover .butn-wrapper a.simple-link{\n    color: rgba(111, 168, 220, 1.0);\n  }\n\n  .cards_gallery_module.widget_1670309355333 .flex_row_card .item.num3{\n    padding: 0 15px;\n  }\n\n  \n  \n\n  .cards_gallery_module.widget_1670309355333 .content-wrapper{\n    padding-top: 20px;\npadding-right: 0px;\npadding-bottom: 20px;\npadding-left: 0px;\n\n  }\n\n  \n\n  \n\n  \n\n\n  @media (max-width: 767px){\n    \n\n    \n\n\n    \n\n    \n\n  }\n\n\n\n\n\n\n\n\n.hs_case_inner_row1-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row2-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row2-row-2-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row3-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row3-row-1-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n/* HubSpot Styles (default) */\n.hs_case_inner_row1-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row2-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row2-row-2-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.cell_16703083218312-padding {\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.cell_16703093224762-padding {\n  padding-left: 0px !important;\n  padding-rig ...
#  Document(text='\n\nFocused Labs\n\n\n\n      var show = localStorage.getItem(\'show\');\n      if(show === \'true\'){\n        document.documentElement.classList.add(\'dark\');\n      } \n    \n\nhsjQuery = window[\'jQuery\'];\n\n\n\n\n\na.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:\'›\';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}\n\n\n\n\n\n\n\n\n\n.hs_case_inner_row1-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row3-row-0-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n.hs_case_inner_row3-row-1-force-full-width-section > .row-fluid {\n  max-width: none !important;\n}\n/* HubSpot Styles (default) */\n.hs_case_inner_row1-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.cell_16703083218312-padding {\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row3-row-0-padding {\n  padding-top: 0px !important;\n  padding-bottom: 0px !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n.hs_case_inner_row3-row-1-padding {\n  padding-top: 0px !important;\n  padding-bottom: 7.5rem !important;\n  padding-left: 0px !important;\n  padding-right: 0px !important;\n}\n\n\n\n\n\nvar _hsp = window._hsp = window._hsp || [];\n\nvar hsLoadGtm = function loadGtm() {\n    if(window._hsGtmLoadOnce) {\n      return;\n    }\n\n    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-MGP2TJH\');\n\n    window._hsGtmLoadOnce = true;\n};\n\nvar useGoogleConsentMode = false;\n\nif (!useGoogleConsentMode){\n    _hsp.push([\'addPrivacyConsentListener\', function(consent){\n      if(consent.allowed || (consent.categories && consent.categories.analytics)){\n        hsLoadGtm();\n      }\n  }]);\n} else{\n    if(!window._hsGoogleConsentRunOnce){\n      window._hsGoogleConsentRunOnce=true;\n\n      window.dataLayer=window.dataLayer||[];\n      function gtag(){dataLayer.push(arguments);}\n\n      gtag(\'consent\',\'default\',{\n        \'ad_storage\':\'denied\',\n        \'analytics_storage\':\'denied\'\n      });\n\n      gtag(\'set\',\'developer_id.dZTQ1Zm\',true);\n\n      _hsp.push([\'addPrivacyConsentListener\',function(consent){\n      var hasAnalyticsConsent=consent&&(consent.allowed||(consent.categories&&consent.categories.analytics));\n      var hasAdsConsent=consent&&(consent.allowed||(consent.categories&&consent.categories.advertisement));\n\n      gtag(\'consent\',\'update\',{\n        \'ad_storage\':hasAdsConsent?\'granted\':\'denied\',\n        \'analytics_storage\':hasAnalyticsConsent?\'granted\':\'denied\'\n      });\n    }]);\n  }\n\n  hsLoadGtm();\n}\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout\nServices\nBlog\nCareers\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCase study\n\n\n\n\n\n\n\n\n\nAutomating Core Business Functionality at Inner Matrix Systems\n\n\nIndustry\nWellness\n\n\n\n\n\n\n\n\n\n\n\ ...

# %%
import logging
import sys

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
from transformers import normalize_text

for document in documents:
    document.text = normalize_text(document.text)

# %%
from llama_index import GPTVectorStoreIndex
from llama_index.vector_stores import RedisVectorStore
from config import OPENAI_API_KEY, INDEX_NAME, PREFIX
from llama_index.storage.storage_context import StorageContext
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

vector_store = RedisVectorStore(
    index_name=INDEX_NAME,
    index_prefix=PREFIX,
    redis_url="redis://localhost:6379",
    overwrite=True,
)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = GPTVectorStoreIndex.from_documents(documents, storage_context=storage_context)
# index.index_id = INDEX_NAME

vector_store.persist(persist_path="")
# index = GPTVectorStoreIndex.from_documents(documents)
# Out:
# INFO:llama_index.vector_stores.redis:Creating index fl-index
# Creating index fl-index
# INFO:llama_index.vector_stores.redis:Added 50 documents to index fl-index
# Added 50 documents to index fl-index
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total LLM token usage: 0 tokens
# > [build_index_from_nodes] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [build_index_from_nodes] Total embedding token usage: 44898 tokens
# > [build_index_from_nodes] Total embedding token usage: 44898 tokens
# INFO:llama_index.vector_stores.redis:Saving index to disk in background
# Saving index to disk in background

# %%
# Check that our docs have been inserted
redis_client.ft(INDEX_NAME).info()['num_docs']
# Out:
# '109'

# %%
# set Logging to DEBUG for more detailed outputs
query_engine = index.as_query_engine()
response = query_engine.query("What are some of the solutions that Focused Labs has created?")
response
response.response
# Out:
# INFO:llama_index.vector_stores.redis:Using filters: *
# Using filters: *
# INFO:llama_index.vector_stores.redis:Querying index fl-index
# Querying index fl-index
# INFO:llama_index.vector_stores.redis:Found 2 results for query with id ['focusedlabsdoc_95c33ff5-2eb0-4dc7-b5ca-40908d2c7e7b', 'focusedlabsdoc_75b0409b-535b-45d5-9a6c-358ff500764b']
# Found 2 results for query with id ['focusedlabsdoc_95c33ff5-2eb0-4dc7-b5ca-40908d2c7e7b', 'focusedlabsdoc_75b0409b-535b-45d5-9a6c-358ff500764b']
# INFO:llama_index.token_counter.token_counter:> [retrieve] Total LLM token usage: 0 tokens
# > [retrieve] Total LLM token usage: 0 tokens
# INFO:llama_index.token_counter.token_counter:> [retrieve] Total embedding token usage: 13 tokens
# > [retrieve] Total embedding token usage: 13 tokens
# INFO:llama_index.token_counter.token_counter:> [get_response] Total LLM token usage: 2011 tokens
# > [get_response] Total LLM token usage: 2011 tokens
# INFO:llama_index.token_counter.token_counter:> [get_response] Total embedding token usage: 0 tokens
# > [get_response] Total embedding token usage: 0 tokens
# "\nSome of the solutions that Focused Labs has created include streamlining onboarding with BTR Energy's Bridge platform, managing EV charging data, and helping Hertz leverage technology to capture new markets."
